# %%
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
source_dir = '/mnt/data/Downloads/yelp_dataset_challenge_academic_dataset'

businesses = pd.read_csv( os.path.join(source_dir, 'business.csv'), parse_dates=True, index_col='business_id' )
businesses
# Out:
#                                                                attributes  \
# business_id
# 5UmKMjUEUNdYWqANhGckJw  {'Good For': {'breakfast': False, 'latenight':...
# UsFtqoBl7naz8AVUBZMjQQ  {'Happy Hour': True, 'Accepts Credit Cards': T...
# cE27W9VPgO88Qxe4ol6y_g                            {'Good for Kids': True}
# mVHrayjG3uZ_RLHkLj-AMg  {'Good For': {'latenight': False, 'breakfast':...
# mYSpR_SLPgUVymYOvTQd_Q  {'Good for Kids': True, 'Takes Reservations': ...
# KayYbHCt-RkbGcPdGOThNg  {'Good For': {'breakfast': False, 'latenight':...
# b12U9TFESStdy7CsTtcOeg                     {'Accepts Credit Cards': True}
# Sktj1eHQFuVa-M4bgnEh8g                            {'Good for Kids': True}
# 3ZVKmuK2l7uXPE6lXY4Dbg                                                 {}
# QoDa50dc7g62xciFygXB9w                                                 {}
# 1_lU0-eSWJCRvNGk78Zh9Q                                  {'Wi-Fi': 'free'}
# ...

# %%
businesses.stars.value_counts()
# Out:
# 4.0    17456
# 3.5    16624
# 4.5    13648
# 5.0    12964
# 3.0    11023
# 2.5     7447
# 2.0     3777
# 1.5     1890
# 1.0     1072
# Name: stars, dtype: int64

# %%
star_counts = businesses.stars.value_counts(sort=False, normalize=True).sort_index()
star_counts.plot(kind="bar")

# %%
users = pd.read_csv( os.path.join(source_dir, 'user.csv'), parse_dates=True, index_col='user_id' )
users
# Out:
#                         average_stars  \
# user_id
# 18kPq7GPye-YQ3LyKyAZPw           4.14
# rpOyqD_893cqmDAtJLbdog           3.67
# 4U9kSBLuBDU391x6bxU-YA           3.68
# fHtTaujcyKvXglE33Z5yIw           4.64
# SIBCL7HBkrP4llolm4SC2A           3.80
# 8J4IIYcqBlFch8T90N923A           4.35
# ysYmC-ufbdmVEX9yAv-VEQ           4.45
# WPOKvkacSKHx_bIG1alFiA           3.88
# UTS9XcT14H2ZscRIf0MYHQ           3.59
# 1blidZhgxDVSBuJ_dbTU6g           5.00
# qL7Astun3i7qwr2IL5iowA           4.30
# ZWOj6LmzwGvMDh-A85EOtA           4.01
# HDQixQ-WZEV0LVPJlIGQeQ           3.83
# 9i8tV1cWR3nSiOTtg4OEAg           3.69
# bWNn5RzthU9-yo5VYQB20g           4.92
# xu_KA5FxXfb5-vx0uz_BNg           3.60
# 5OlCB4cJ3CUksr3ONw6Ezw           1.33
# e-hBnxMWmzSut-BlyxR2KQ           2.42
# E_DJ1nTDPt9Qk2abWFTefQ           4.38
# LCbwNuo4r-WdAmw6LeGPog           1.00
# xOQVHYN1roRZKpLvAT-a2A           2.50
# Z28E8hEXDoLZUuPcZvnzcg           3.64
# 0ZtOuzEA3k8XjSaf6MgR-w           3.76
# ...

# %%
review_file = os.path.join(source_dir, 'review.csv')

fraction_toread = 100
if fraction_toread <= 1:
    skip_rows = []
else:
    skip_rows = [i for i in range(0, 50000000) if i % fraction_toread != 0]

reviews = pd.read_csv(
    review_file,
    parse_dates=True,
    index_col='review_id',
    skiprows=skip_rows
)
reviews
# Out:
#                                    business_id        date  stars  \
# review_id
# 7N9j5YbBHBW6qguE5DAeyA  UsFtqoBl7naz8AVUBZMjQQ  2014-10-29      1
# 3Es8GsjkssusYgeU6_ZVpQ  mVHrayjG3uZ_RLHkLj-AMg  2013-03-30      5
# RgYjyaOkSY1b5r9wirrfIQ  mVHrayjG3uZ_RLHkLj-AMg  2015-03-16      4
# wjFPIigHK6I0qaBEypilRA  mVHrayjG3uZ_RLHkLj-AMg  2016-04-07      4
# 2_Ru_ASf75kU303rdQjFfQ  KayYbHCt-RkbGcPdGOThNg  2013-04-25      4
# ib7gyGiDZwI2ji1grqWMMw  KayYbHCt-RkbGcPdGOThNg  2015-11-11      4
# 68MM1gPtOoe-squoK43mEw  b12U9TFESStdy7CsTtcOeg  2015-01-27      4
# C2JqxAAroijbe2brkAnpxg  QoDa50dc7g62xciFygXB9w  2014-12-22      5
# kj0kTIV4hoPQv4xlB7jZ2A  _qopVQ6_Mz6W7-Pmbi56GQ  2015-12-17      3
# bMCvh40U7J1xu3IwuulAPg  yXuao0pFz1AxB21vJjDf5w  2011-03-09      3
# vXCN6pPczOtvqDkFw_jywA  Cdcus0NADzyY3XiJM2O5Sg  2015-05-25      3
# fOcK7VKmeD9yqUG35iieuA  fNGIbpazjTRdXgwRY_NIXA  2016-02-13      5
# 522RwFpvxPKwVcJa4C3slw  b9WZJp5L1RZr4F1nxclOoQ  2011-01-05      5
# ...

# %%
rb = pd.merge(reviews, businesses, how='left', left_on='business_id', right_index=True, suffixes=('review', 'business'))
rbu = pd.merge(rb, users, how='left', left_on='user_id', right_index=True, suffixes=('review', 'user'))
rbu
